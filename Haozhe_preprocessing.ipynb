# %%
import numpy as np
import pandas as pd
from utils import preprocess_LIU

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_DIR = "./data/"
TRAIN_DATA_FILE = DATA_DIR + "olid-training-v1.0.tsv"

# %%
ori_train_data = pd.read_csv(TRAIN_DATA_FILE, sep='\t')

# %%
ori_train_data
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  @USER She should ask a few native Americans wh...       OFF
# 1      90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688  @USER Someone should'veTaken" this piece of sh...       OFF
# 4      43605  @USER @USER Obama wanted liberals &amp; illega...       NOT
# ...      ...                                                ...       ...
# 13235  95338  @USER Sometimes I get strong vibes from people...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921  @USER And why report this garbage.  We don't g...       OFF
# 13238  27429                                        @USER Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# ...

# %%
ori_train_data['tweet'] = ori_train_data['tweet'].apply(preprocess_LIU.text_preprocessing_pipeline)

# %%
ori_train_data
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  she should ask a few native americans what the...       OFF
# 1      90194                      go home you re drunk maga url       OFF
# 2      16820  amazon is investigating chinese employees who ...       NOT
# 3      62688  someone should havetaken this piece of shit to...       OFF
# 4      43605  obama wanted liberals illegals to move into re...       NOT
# ...      ...                                                ...       ...
# 13235  95338  sometimes i get strong vibes from people and t...       OFF
# 13236  67210  benidorm creamfields maga not too shabby of a ...       NOT
# 13237  82921  and why report this garbage we do not give a crap       OFF
# 13238  27429                                              pussy       OFF
# 13239  46552  spanishrevenge vs justice humanrights and free...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# ...
